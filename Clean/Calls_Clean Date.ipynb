# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ls drive/MyDrive/'Final_Project_ICH'/'CSV_file'/

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt

# %% [markdown]
# # Очистка данных в таблице **Calls**
# - преобразование формата данных Id, CONTACTID строчный форомат(object)
# - преобразование дат в формат datetime
# - проверка дубликатов и их удаление
# - удаление пустых(не релевантных) столбцов
# - просмотр уникальных значений
# - проверка значений NaN
# - замена типа данных на категориальные Call Owner Name, Call Type, Call Status, Outgoing Call Status, Scheduled in CRM
# - заполнение/замена значений категориальных NaN = Unknown
# - контроль данных и значений

# %%
calls_df = pd.read_csv('drive/MyDrive/Final_Project_ICH/CSV_file/Calls.csv', dtype={"Id": 'str', 'CONTACTID': 'str'})
#calls_df.info()
calls_df.head()
# Out:
#                     Id   Call Start Time Call Owner Name            CONTACTID  \
# 0  5805028000000805001  30.06.2023 08:43        John Doe                  NaN
# 1  5805028000000768006  30.06.2023 08:46        John Doe                  NaN
# 2  5805028000000764027  30.06.2023 08:59        John Doe                  NaN
# 3  5805028000000787003  30.06.2023 09:20        John Doe  5805028000000645014
# 4  5805028000000768019  30.06.2023 09:30        John Doe  5805028000000645014
#
#   Call Type  Call Duration (in seconds)       Call Status  Dialled Number  \
# 0   Inbound                       171.0          Received             NaN
# 1  Outbound                        28.0  Attended Dialled             NaN
# 2  Outbound                        24.0  Attended Dialled             NaN
# 3  Outbound                         6.0  Attended Dialled             NaN
# 4  Outbound                        11.0  Attended Dialled             NaN
#
#   Outgoing Call Status Scheduled in CRM  Tag
# 0                  NaN              NaN  NaN
# 1            Completed            False  NaN
# 2            Completed            False  NaN
# 3            Completed            False  NaN
# 4            Completed            False  NaN

# %%
# Преобразование формата дат
calls_df["Call Start Time"] = pd.to_datetime(calls_df["Call Start Time"], format="%d.%m.%Y %H:%M", errors='coerce')

# %%
calls_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95874 entries, 0 to 95873
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Id                          95874 non-null  object
#  1   Call Start Time             95874 non-null  datetime64[ns]
#  2   Call Owner Name             95874 non-null  object
#  3   CONTACTID                   91941 non-null  object
#  4   Call Type                   95874 non-null  object
#  5   Call Duration (in seconds)  95791 non-null  float64
#  6   Call Status                 95874 non-null  object
#  7   Dialled Number              0 non-null      float64
#  8   Outgoing Call Status        86875 non-null  object
#  9   Scheduled in CRM            86875 non-null  object
#  10  Tag                         0 non-null      float64
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 8.0+ MB

# %%
# удаление пустых колонок
calls_df.drop(['Tag', 'Dialled Number'], axis=1, inplace=True)

# %%
# проверка дубликатов
calls_df[calls_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, Call Start Time, Call Owner Name, CONTACTID, Call Type, Call Duration (in seconds), Call Status, Outgoing Call Status, Scheduled in CRM]
# Index: []

# %%
calls_df['Scheduled in CRM'].value_counts()
# Out:
# Scheduled in CRM
# False    86733
# True       142
# Name: count, dtype: int64

# %%
calls_df['Call Type'].value_counts()
# Out:
# Call Type
# Outbound    86875
# Missed       5921
# Inbound      3078
# Name: count, dtype: int64

# %%
calls_df['Call Status'].value_counts()
# Out:
# Call Status
# Attended Dialled              70703
# Unattended Dialled            16030
# Missed                         5922
# Received                       3077
# Overdue                          60
# Scheduled Attended Delay         22
# Cancelled                        20
# Scheduled Unattended Delay       17
# Scheduled Attended               14
# Scheduled Unattended              6
# Scheduled                         3
# Name: count, dtype: int64

# %%
calls_df['Outgoing Call Status'].value_counts()
# Out:
# Outgoing Call Status
# Completed    86792
# Overdue         60
# Cancelled       20
# Scheduled        3
# Name: count, dtype: int64

# %%
calls_df.isnull().sum()
# Out:
# Id                               0
# Call Start Time                  0
# Call Owner Name                  0
# CONTACTID                     3933
# Call Type                        0
# Call Duration (in seconds)      83
# Call Status                      0
# Outgoing Call Status          8999
# Scheduled in CRM              8999
# dtype: int64

# %%
calls_df.shape
# Out:
# (95874, 9)

# %%
calls_df[calls_df['CONTACTID'].isnull()]
# Out:
#                         Id     Call Start Time Call Owner Name CONTACTID  \
# 0      5805028000000805001 2023-06-30 08:43:00        John Doe       NaN
# 1      5805028000000768006 2023-06-30 08:46:00        John Doe       NaN
# 2      5805028000000764027 2023-06-30 08:59:00        John Doe       NaN
# 7      5805028000000879006 2023-07-03 13:06:00      Jane Smith       NaN
# 8      5805028000000870005 2023-07-03 13:08:00      Jane Smith       NaN
# ...                    ...                 ...             ...       ...
# 95852  5805028000056849471 2024-06-21 15:06:00   Ulysses Adams       NaN
# 95853  5805028000056859477 2024-06-21 15:07:00   Ulysses Adams       NaN
# 95861  5805028000056876318 2024-06-21 15:20:00        Eva Kent       NaN
# 95868  5805028000056912329 2024-06-21 15:30:00   Victor Barnes       NaN
# 95873  5805028000056893631 2024-06-21 15:31:00        John Doe       NaN
#
#       Call Type  Call Duration (in seconds)         Call Status  \
# 0       Inbound                       171.0            Received
# 1      Outbound                        28.0    Attended Dialled
# 2      Outbound                        24.0    Attended Dialled
# 7      Outbound                         0.0  Unattended Dialled
# 8      Outbound                        40.0    Attended Dialled
# ...         ...                         ...                 ...
# 95852  Outbound                         7.0    Attended Dialled
# 95853   Inbound                       407.0            Received
# 95861  Outbound                         5.0    Attended Dialled
# 95868  Outbound                         NaN           Scheduled
# 95873    Missed                         0.0              Missed
#
#       Outgoing Call Status Scheduled in CRM
# 0                      NaN              NaN
# 1                Completed            False
# 2                Completed            False
# 7                Completed            False
# 8                Completed            False
# ...                    ...              ...
# 95852            Completed            False
# 95853                  NaN              NaN
# 95861            Completed            False
# 95868            Scheduled             True
# 95873                  NaN              NaN
#
# [3933 rows x 9 columns]

# %%
# Получение уникальных значений в столбце 'Contact Owner Name'
unique_values = calls_df['Call Owner Name'].unique()
unique_values
# Out:
# array(['John Doe', 'Jane Smith', 'Alice Johnson', 'Bob Brown',
#        'Charlie Davis', 'Diana Evans', 'Ethan Harris', 'Fiona Jackson',
#        'George King', 'Hannah Lee', 'Ian Miller', 'Julia Nelson',
#        'Kevin Parker', 'Laura Quinn', 'Mason Roberts', 'Nina Scott',
#        'Oliver Taylor', 'Paula Underwood', 'Quincy Vincent',
#        'Rachel White', 'Sam Young', 'Tina Zhang', 'Ulysses Adams',
#        'Victor Barnes', 'Wendy Clark', 'Xander Dean', 'Yara Edwards',
#        'Zachary Foster', 'Amy Green', 'Ben Hall', 'Cara Iverson',
#        'Derek James', 'Eva Kent'], dtype=object)

# %%
calls_df['Call Owner Name'].nunique()
# Out:
# 33

# %%
calls_df['CONTACTID'].nunique()
# Out:
# 15214

# %%
calls_df[calls_df['Call Duration (in seconds)'].isnull()]
# Out:
#                         Id     Call Start Time Call Owner Name  \
# 21711  5805028000012419809 2023-11-15 15:00:00    Kevin Parker
# 36095  5805028000012419971 2024-01-15 15:00:00    Kevin Parker
# 36096  5805028000012419512 2024-01-15 15:00:00    Kevin Parker
# 37600  5805028000026957356 2024-01-19 10:00:00   Victor Barnes
# 37607  5805028000026466529 2024-01-19 10:30:00   Victor Barnes
# ...                    ...                 ...             ...
# 89073  5805028000053636072 2024-06-05 17:00:00   Victor Barnes
# 89257  5805028000053651109 2024-06-06 07:00:00   Victor Barnes
# 92959  5805028000055092068 2024-06-14 16:00:00   Victor Barnes
# 93676  5805028000055626456 2024-06-17 10:00:00   Victor Barnes
# 95868  5805028000056912329 2024-06-21 15:30:00   Victor Barnes
#
#                  CONTACTID Call Type  Call Duration (in seconds) Call Status  \
# 21711                  NaN  Outbound                         NaN   Cancelled
# 36095                  NaN  Outbound                         NaN     Overdue
# 36096                  NaN  Outbound                         NaN     Overdue
# 37600                  NaN  Outbound                         NaN     Overdue
# 37607  5805028000021065227  Outbound                         NaN     Overdue
# ...                    ...       ...                         ...         ...
# 89073                  NaN  Outbound                         NaN     Overdue
# 89257                  NaN  Outbound                         NaN   Cancelled
# 92959                  NaN  Outbound                         NaN   Scheduled
# 93676                  NaN  Outbound                         NaN   Scheduled
# 95868                  NaN  Outbound                         NaN   Scheduled
#
#       Outgoing Call Status Scheduled in CRM
# 21711            Cancelled             True
# 36095              Overdue             True
# 36096              Overdue             True
# 37600              Overdue             True
# 37607              Overdue             True
# ...                    ...              ...
# 89073              Overdue             True
# 89257            Cancelled             True
# 92959            Scheduled             True
# 93676            Scheduled             True
# 95868            Scheduled             True
#
# [83 rows x 9 columns]

# %%
calls_df[calls_df['Call Status']== 'Scheduled']
# Out:
#                         Id     Call Start Time Call Owner Name CONTACTID  \
# 92959  5805028000055092068 2024-06-14 16:00:00   Victor Barnes       NaN
# 93676  5805028000055626456 2024-06-17 10:00:00   Victor Barnes       NaN
# 95868  5805028000056912329 2024-06-21 15:30:00   Victor Barnes       NaN
#
#       Call Type  Call Duration (in seconds) Call Status Outgoing Call Status  \
# 92959  Outbound                         NaN   Scheduled            Scheduled
# 93676  Outbound                         NaN   Scheduled            Scheduled
# 95868  Outbound                         NaN   Scheduled            Scheduled
#
#       Scheduled in CRM
# 92959             True
# 93676             True
# 95868             True

# %%
# Заменяем значения в столбце "Call Duration (in seconds)" на 0, если "Call Status" == "Overdue"
calls_df.loc[calls_df['Call Status'] == 'Scheduled', 'Call Duration (in seconds)'] = 0

# %%
calls_df[calls_df['Call Status']== 'Cancelled']
# Out:
#                         Id     Call Start Time Call Owner Name CONTACTID  \
# 21711  5805028000012419809 2023-11-15 15:00:00    Kevin Parker       NaN
# 39785  5805028000028203333 2024-01-25 12:00:00   Victor Barnes       NaN
# 42685  5805028000012419105 2024-02-01 15:00:00    Kevin Parker       NaN
# 45662  5805028000012635140 2024-02-10 18:00:00    Kevin Parker       NaN
# 50216  5805028000012419919 2024-02-25 15:00:00    Kevin Parker       NaN
# 67870  5805028000043554064 2024-04-12 16:30:00   Victor Barnes       NaN
# 67871  5805028000043267197 2024-04-12 16:30:00   Victor Barnes       NaN
# 68597  5805028000043831431 2024-04-15 17:30:00   Victor Barnes       NaN
# 71214  5805028000045147916 2024-04-21 15:45:00   Victor Barnes       NaN
# 71382  5805028000045343826 2024-04-22 09:30:00   Victor Barnes       NaN
# 71656  5805028000045343541 2024-04-22 15:00:00   Victor Barnes       NaN
# 73193  5805028000045963383 2024-04-25 13:00:00    Julia Nelson       NaN
# 78858  5805028000049172493 2024-05-11 11:00:00        Eva Kent       NaN
# 80357  5805028000049948136 2024-05-14 18:30:00   Victor Barnes       NaN
# 82027  5805028000050442095 2024-05-17 19:30:00   Victor Barnes       NaN
# 82566  5805028000050901431 2024-05-20 16:00:00   Victor Barnes       NaN
# 82597  5805028000050901853 2024-05-20 17:10:00   Victor Barnes       NaN
# 86351  5805028000050150249 2024-05-30 10:00:00   Victor Barnes       NaN
# 87823  5805028000052890292 2024-06-03 13:00:00   Victor Barnes       NaN
# 89257  5805028000053651109 2024-06-06 07:00:00   Victor Barnes       NaN
#
#       Call Type  Call Duration (in seconds) Call Status Outgoing Call Status  \
# 21711  Outbound                         NaN   Cancelled            Cancelled
# 39785  Outbound                         NaN   Cancelled            Cancelled
# 42685  Outbound                         NaN   Cancelled            Cancelled
# 45662  Outbound                         NaN   Cancelled            Cancelled
# 50216  Outbound                         NaN   Cancelled            Cancelled
# 67870  Outbound                         NaN   Cancelled            Cancelled
# 67871  Outbound                         NaN   Cancelled            Cancelled
# 68597  Outbound                         NaN   Cancelled            Cancelled
# 71214  Outbound                         NaN   Cancelled            Cancelled
# 71382  Outbound                         NaN   Cancelled            Cancelled
# 71656  Outbound                         NaN   Cancelled            Cancelled
# 73193  Outbound                         NaN   Cancelled            Cancelled
# 78858  Outbound                         NaN   Cancelled            Cancelled
# 80357  Outbound                         NaN   Cancelled            Cancelled
# 82027  Outbound                         NaN   Cancelled            Cancelled
# 82566  Outbound                         NaN   Cancelled            Cancelled
# 82597  Outbound                         NaN   Cancelled            Cancelled
# 86351  Outbound                         NaN   Cancelled            Cancelled
# 87823  Outbound                         NaN   Cancelled            Cancelled
# 89257  Outbound                         NaN   Cancelled            Cancelled
#
#       Scheduled in CRM
# 21711             True
# 39785             True
# 42685             True
# 45662             True
# 50216             True
# 67870             True
# 67871             True
# 68597             True
# 71214             True
# 71382             True
# 71656             True
# 73193             True
# 78858             True
# 80357             True
# 82027             True
# 82566             True
# 82597             True
# 86351             True
# 87823             True
# 89257             True

# %%
# Заменяем значения в столбце "Call Duration (in seconds)" на 0, если "Call Status" == "Overdue"
calls_df.loc[calls_df['Call Status'] == 'Cancelled', 'Call Duration (in seconds)'] = 0

# %%
calls_df[calls_df['Call Status']== 'Overdue']
# Out:
#                         Id     Call Start Time Call Owner Name  \
# 36095  5805028000012419971 2024-01-15 15:00:00    Kevin Parker
# 36096  5805028000012419512 2024-01-15 15:00:00    Kevin Parker
# 37600  5805028000026957356 2024-01-19 10:00:00   Victor Barnes
# 37607  5805028000026466529 2024-01-19 10:30:00   Victor Barnes
# 37623  5805028000026957294 2024-01-19 11:00:00   Victor Barnes
# 37972  5805028000027189639 2024-01-19 19:40:00   Victor Barnes
# 38236  5805028000026738099 2024-01-21 13:00:00   Victor Barnes
# 38237  5805028000027189317 2024-01-21 13:00:00   Victor Barnes
# 38383  5805028000027542172 2024-01-22 10:00:00   Victor Barnes
# 38439  5805028000027189233 2024-01-22 13:00:00   Victor Barnes
# 39171  5805028000027189415 2024-01-24 11:00:00   Victor Barnes
# 39427  5805028000027708335 2024-01-24 16:00:00   Victor Barnes
# 39561  5805028000028111394 2024-01-24 18:10:00   Victor Barnes
# 39621  5805028000026957014 2024-01-24 19:30:00   Victor Barnes
# 39627  5805028000027669031 2024-01-24 20:00:00   Victor Barnes
# 39822  5805028000028203082 2024-01-25 12:30:00   Victor Barnes
# 39946  5805028000028111445 2024-01-25 15:00:00   Victor Barnes
# 39976  5805028000028203530 2024-01-25 16:00:00   Victor Barnes
# 40162  5805028000028274175 2024-01-26 09:00:00   Victor Barnes
# 40198  5805028000027708215 2024-01-26 11:00:00   Victor Barnes
# 40457  5805028000028203497 2024-01-26 19:00:00   Victor Barnes
# 40727  5805028000028203378 2024-01-28 12:00:00   Victor Barnes
# 40728  5805028000028203429 2024-01-28 12:00:00   Victor Barnes
# 40755  5805028000028396893 2024-01-28 14:00:00   Victor Barnes
# 42097  5805028000029255207 2024-01-31 12:30:00   Victor Barnes
# 42686  5805028000012419627 2024-02-01 15:00:00    Kevin Parker
# 45394  5805028000012419653 2024-02-09 15:00:00    Kevin Parker
# 45626  5805028000012419071 2024-02-10 15:00:00    Kevin Parker
# 45927  5805028000031491095 2024-02-12 16:00:00   Victor Barnes
# 50251  5805028000034085068 2024-02-25 17:00:00   Victor Barnes
# 67380  5805028000043230050 2024-04-11 17:10:00   Victor Barnes
# 67403  5805028000043156591 2024-04-11 17:30:00   Victor Barnes
# 67837  5805028000043554095 2024-04-12 16:00:00   Victor Barnes
# 67919  5805028000043554289 2024-04-12 18:30:00   Victor Barnes
# 68315  5805028000043554143 2024-04-15 10:00:00   Victor Barnes
# 68579  5805028000043831666 2024-04-15 17:00:00   Victor Barnes
# 68629  5805028000043831744 2024-04-15 18:00:00   Victor Barnes
# 68652  5805028000043831931 2024-04-15 18:30:00   Victor Barnes
# 71368  5805028000045343123 2024-04-21 19:00:00   Victor Barnes
# 71729  5805028000045471619 2024-04-22 16:30:00   Victor Barnes
# 71821  5805028000045571004 2024-04-22 18:00:00   Victor Barnes
# 73139  5805028000046290006 2024-04-25 12:00:00  Quincy Vincent
# 73290  5805028000046445096 2024-04-25 14:30:00   Victor Barnes
# 73699  5805028000046445278 2024-04-26 12:00:00   Victor Barnes
# 73858  5805028000046845126 2024-04-26 16:00:00   Victor Barnes
# 73928  5805028000046792060 2024-04-26 18:00:00   Victor Barnes
# 74504  5805028000047119015 2024-04-28 17:00:00   Victor Barnes
# 74671  5805028000046845260 2024-04-29 12:12:00   Victor Barnes
# 74711  5805028000047042553 2024-04-29 13:00:00   Victor Barnes
# 78310  5805028000048662011 2024-05-09 15:00:00   Victor Barnes
# 78736  5805028000049131338 2024-05-10 17:00:00   Victor Barnes
# 78861  5805028000049324202 2024-05-11 11:15:00        Eva Kent
# 78897  5805028000049324514 2024-05-11 13:00:00        Eva Kent
# 79553  5805028000049172593 2024-05-13 15:00:00   Victor Barnes
# 80048  5805028000049918362 2024-05-14 14:30:00   Victor Barnes
# 80464  5805028000049948471 2024-05-15 10:00:00   Victor Barnes
# 81665  5805028000050256990 2024-05-17 10:00:00   Victor Barnes
# 81935  5805028000050442128 2024-05-17 16:00:00   Victor Barnes
# 89034  5805028000053636096 2024-06-05 16:30:00   Victor Barnes
# 89073  5805028000053636072 2024-06-05 17:00:00   Victor Barnes
#
#                  CONTACTID Call Type  Call Duration (in seconds) Call Status  \
# 36095                  NaN  Outbound                         NaN     Overdue
# 36096                  NaN  Outbound                         NaN     Overdue
# 37600                  NaN  Outbound                         NaN     Overdue
# 37607  5805028000021065227  Outbound                         NaN     Overdue
# 37623                  NaN  Outbound                         NaN     Overdue
# 37972                  NaN  Outbound                         NaN     Overdue
# 38236                  NaN  Outbound                         NaN     Overdue
# 38237                  NaN  Outbound                         NaN     Overdue
# 38383  5805028000026965161  Outbound                         NaN     Overdue
# 38439                  NaN  Outbound                         NaN     Overdue
# 39171                  NaN  Outbound                         NaN     Overdue
# 39427                  NaN  Outbound                         NaN     Overdue
# 39561                  NaN  Outbound                         NaN     Overdue
# 39621                  NaN  Outbound                         NaN     Overdue
# 39627                  NaN  Outbound                         NaN     Overdue
# 39822                  NaN  Outbound                         NaN     Overdue
# 39946                  NaN  Outbound                         NaN     Overdue
# 39976                  NaN  Outbound                         NaN     Overdue
# 40162                  NaN  Outbound                         NaN     Overdue
# 40198                  NaN  Outbound                         NaN     Overdue
# 40457                  NaN  Outbound                         NaN     Overdue
# 40727                  NaN  Outbound                         NaN     Overdue
# 40728                  NaN  Outbound                         NaN     Overdue
# 40755                  NaN  Outbound                         NaN     Overdue
# 42097                  NaN  Outbound                         NaN     Overdue
# 42686                  NaN  Outbound                         NaN     Overdue
# 45394                  NaN  Outbound                         NaN     Overdue
# 45626                  NaN  Outbound                         NaN     Overdue
# 45927                  NaN  Outbound                         NaN     Overdue
# 50251                  NaN  Outbound                         NaN     Overdue
# 67380                  NaN  Outbound                         NaN     Overdue
# 67403                  NaN  Outbound                         NaN     Overdue
# 67837                  NaN  Outbound                         NaN     Overdue
# 67919                  NaN  Outbound                         NaN     Overdue
# 68315                  NaN  Outbound                         NaN     Overdue
# 68579                  NaN  Outbound                         NaN     Overdue
# 68629                  NaN  Outbound                         NaN     Overdue
# 68652                  NaN  Outbound                         NaN     Overdue
# 71368                  NaN  Outbound                         NaN     Overdue
# 71729                  NaN  Outbound                         NaN     Overdue
# 71821  5805028000030143280  Outbound                         NaN     Overdue
# 73139  5805028000018056036  Outbound                         NaN     Overdue
# 73290                  NaN  Outbound                         NaN     Overdue
# 73699                  NaN  Outbound                         NaN     Overdue
# 73858                  NaN  Outbound                         NaN     Overdue
# 73928                  NaN  Outbound                         NaN     Overdue
# 74504                  NaN  Outbound                         NaN     Overdue
# 74671                  NaN  Outbound                         NaN     Overdue
# 74711                  NaN  Outbound                         NaN     Overdue
# 78310                  NaN  Outbound                         NaN     Overdue
# 78736                  NaN  Outbound                         NaN     Overdue
# 78861                  NaN  Outbound                         NaN     Overdue
# 78897                  NaN  Outbound                         NaN     Overdue
# 79553                  NaN  Outbound                         NaN     Overdue
# 80048  5805028000012498013  Outbound                         NaN     Overdue
# 80464                  NaN  Outbound                         NaN     Overdue
# 81665                  NaN  Outbound                         NaN     Overdue
# 81935                  NaN  Outbound                         NaN     Overdue
# 89034                  NaN  Outbound                         NaN     Overdue
# 89073                  NaN  Outbound                         NaN     Overdue
#
#       Outgoing Call Status Scheduled in CRM
# 36095              Overdue             True
# 36096              Overdue             True
# 37600              Overdue             True
# 37607              Overdue             True
# 37623              Overdue             True
# 37972              Overdue             True
# 38236              Overdue             True
# 38237              Overdue             True
# 38383              Overdue             True
# 38439              Overdue             True
# 39171              Overdue             True
# 39427              Overdue             True
# 39561              Overdue             True
# 39621              Overdue             True
# 39627              Overdue             True
# 39822              Overdue             True
# 39946              Overdue             True
# 39976              Overdue             True
# 40162              Overdue             True
# 40198              Overdue             True
# 40457              Overdue             True
# 40727              Overdue             True
# 40728              Overdue             True
# 40755              Overdue             True
# 42097              Overdue             True
# 42686              Overdue             True
# 45394              Overdue             True
# 45626              Overdue             True
# 45927              Overdue             True
# 50251              Overdue             True
# 67380              Overdue             True
# 67403              Overdue             True
# 67837              Overdue             True
# 67919              Overdue             True
# 68315              Overdue             True
# 68579              Overdue             True
# 68629              Overdue             True
# 68652              Overdue             True
# 71368              Overdue             True
# 71729              Overdue             True
# 71821              Overdue             True
# 73139              Overdue             True
# 73290              Overdue             True
# 73699              Overdue             True
# 73858              Overdue             True
# 73928              Overdue             True
# 74504              Overdue             True
# 74671              Overdue             True
# 74711              Overdue             True
# 78310              Overdue             True
# 78736              Overdue             True
# 78861              Overdue             True
# 78897              Overdue             True
# 79553              Overdue             True
# 80048              Overdue             True
# 80464              Overdue             True
# 81665              Overdue             True
# 81935              Overdue             True
# 89034              Overdue             True
# 89073              Overdue             True

# %%
# Заменяем значения в столбце "Call Duration (in seconds)" на 0, если "Call Status" == "Overdue"
calls_df.loc[calls_df['Call Status'] == 'Overdue', 'Call Duration (in seconds)'] = 0

# %%
calls_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95874 entries, 0 to 95873
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Id                          95874 non-null  object
#  1   Call Start Time             95874 non-null  datetime64[ns]
#  2   Call Owner Name             95874 non-null  object
#  3   CONTACTID                   91941 non-null  object
#  4   Call Type                   95874 non-null  object
#  5   Call Duration (in seconds)  95874 non-null  float64
#  6   Call Status                 95874 non-null  object
#  7   Outgoing Call Status        86875 non-null  object
#  8   Scheduled in CRM            86875 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 6.6+ MB

# %%
category_columns = ['Call Owner Name', 'Call Type', 'Call Status', 'Outgoing Call Status', 'Scheduled in CRM']
for col in category_columns:
    calls_df[col] = calls_df[col].fillna('Unknown')

# %%
calls_df['Scheduled in CRM'] = calls_df['Scheduled in CRM'].astype(str)

# %%
calls_df.info()
calls_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95874 entries, 0 to 95873
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Id                          95874 non-null  object
#  1   Call Start Time             95874 non-null  datetime64[ns]
#  2   Call Owner Name             95874 non-null  object
#  3   CONTACTID                   91941 non-null  object
#  4   Call Type                   95874 non-null  object
#  5   Call Duration (in seconds)  95874 non-null  float64
#  6   Call Status                 95874 non-null  object
#  7   Outgoing Call Status        95874 non-null  object
#  8   Scheduled in CRM            95874 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 6.6+ MB
# Id                               0
# Call Start Time                  0
# Call Owner Name                  0
# CONTACTID                     3933
# Call Type                        0
# Call Duration (in seconds)       0
# Call Status                      0
# Outgoing Call Status             0
# Scheduled in CRM                 0
# dtype: int64

# %% [markdown]
# # **Описательная статистика**

# %%
# сводная статистика для числовых столбцов
numeric_stats = calls_df.describe()
display(numeric_stats)
# Out:
#                      Call Start Time  Call Duration (in seconds)
# count                          95874                95874.000000
# mean   2024-02-05 12:34:44.369484800                  164.834439
# min              2023-06-30 08:43:00                    0.000000
# 25%              2023-11-24 11:07:30                    4.000000
# 50%              2024-02-19 12:19:30                    8.000000
# 75%              2024-04-22 19:10:00                   97.000000
# max              2024-06-21 15:31:00                 7625.000000
# std                              NaN                  401.266369

# %%
calls_df['CONTACTID'].value_counts()
# Out:
# CONTACTID
# 5805028000003329100    94
# 5805028000008246089    72
# 5805028000007866898    70
# 5805028000001880249    67
# 5805028000002799040    57
#                        ..
# 5805028000021705633     1
# 5805028000021694761     1
# 5805028000056892018     1
# 5805028000040210894     1
# 5805028000056833279     1
# Name: count, Length: 15214, dtype: int64

# %%
# Вывод количества уникальных значений и их частоты для каждой категориальной переменной

for col in calls_df.select_dtypes(include=['object']).columns:
    print(f"\nСтатистика по {col}:")
    print(calls_df[col].value_counts().head(100))  # Выводим 100 значений
    print("-" * 50)  # Разделитель для удобства чтения
# Out:
# Статистика по Id:
# Id
# 5.80503E+18            3
# 5805028000041757323    1
# 5805028000041753189    1
# 5805028000041733204    1
# 5805028000041734423    1
#                       ..
# 5805028000041755675    1
# 5805028000041752614    1
# 5805028000041766422    1
# 5805028000041753328    1
# 5805028000041753316    1
# Name: count, Length: 100, dtype: int64
# --------------------------------------------------
#
# Статистика по Call Owner Name:
# Call Owner Name
# Yara Edwards       9059
# Julia Nelson       7446
# Ian Miller         7215
# Charlie Davis      7213
# Diana Evans        6857
# Ulysses Adams      6085
# Amy Green          5982
# Nina Scott         5581
# Victor Barnes      5439
# Kevin Parker       5406
# Paula Underwood    4580
# Quincy Vincent     4384
# Jane Smith         3753
# Cara Iverson       3300
# John Doe           2986
# Ben Hall           2947
# Alice Johnson      1251
# Mason Roberts      1166
# Derek James         948
# George King         850
# Zachary Foster      523
# Eva Kent            498
# Fiona Jackson       470
# Sam Young           457
# Rachel White        441
# Xander Dean         304
# Ethan Harris        280
# Hannah Lee          175
# Wendy Clark         162
# Bob Brown            99
# Oliver Taylor        10
# Tina Zhang            5
# Laura Quinn           2
# Name: count, dtype: int64
# --------------------------------------------------
#
# Статистика по CONTACTID:
# CONTACTID
# 5805028000003329100    94
# 5805028000008246089    72
# 5805028000007866898    70
# 5805028000001880249    67
# 5805028000002799040    57
#                        ..
# 5805028000029236399    29
# 5805028000045961052    29
# 5805028000018408794    29
# 5805028000042700966    29
# 5805028000000964025    28
# Name: count, Length: 100, dtype: int64
# --------------------------------------------------
#
# Статистика по Call Type:
# Call Type
# Outbound    86875
# Missed       5921
# Inbound      3078
# Name: count, dtype: int64
# --------------------------------------------------
#
# Статистика по Call Status:
# Call Status
# Attended Dialled              70703
# Unattended Dialled            16030
# Missed                         5922
# Received                       3077
# Overdue                          60
# Scheduled Attended Delay         22
# Cancelled                        20
# Scheduled Unattended Delay       17
# Scheduled Attended               14
# Scheduled Unattended              6
# Scheduled                         3
# Name: count, dtype: int64
# --------------------------------------------------
#
# Статистика по Outgoing Call Status:
# Outgoing Call Status
# Completed    86792
# Unknown       8999
# Overdue         60
# Cancelled       20
# Scheduled        3
# Name: count, dtype: int64
# --------------------------------------------------
#
# Статистика по Scheduled in CRM:
# Scheduled in CRM
# False      86733
# Unknown     8999
# True         142
# Name: count, dtype: int64
# --------------------------------------------------

# %%
calls_df.to_csv('drive/MyDrive/Final_Project_ICH/Clean_file/CallsClean.csv')
calls_df.to_parquet('drive/MyDrive/Final_Project_ICH/Clean_file/CallsClean.parquet')
